# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tqdm import tqdm

from dice_rl_TU_Vienna.value import get_w_prod, get_get_policy_value
from dice_rl_TU_Vienna.plot.general import plot_histogram
from dice_rl_TU_Vienna.plot.tabular import plot_pvs
from dice_rl_TU_Vienna.estimators.tabular.tabular_dice import TabularDice
from dice_rl_TU_Vienna.utils.seeds import set_all_seeds
from dice_rl_TU_Vienna.utils.bedtime import computer_sleep

# %%
version = "v1.0"

dir_data   = os.path.join("data",   "medical_rl", "sepsis_mimic_iv", version)
dir_images = os.path.join("images", "medical_rl", "sepsis_mimic_iv", version)

# %%
kinds = ["behavior", "evaluation"]

# %%
split = pd.read_parquet( os.path.join(dir_data, "split.parquet") )

# %%
def get_IS_quotient_prods(split):
    IS_quotients = []
    IS_quotient_prods = []

    for id in tqdm(split["icustayid"].unique()):
        trajectory = split[split["icustayid"] == id]
        IS_quotients_trajectory = []

        for t, row in trajectory.iterrows():
            if t == len(trajectory) - 1: break

            probs = row["model_probs"]
            probs_behavior = row["phys_probs"]
            act = row["action"]

            IS_quotient = probs[act] / probs_behavior[act]
            IS_quotients.append(IS_quotient)
            IS_quotients_trajectory.append(IS_quotient)

        IS_quotient_prods.append( np.prod(IS_quotients) )

    return IS_quotients, IS_quotient_prods

IS_quotients, IS_quotient_prods = get_IS_quotient_prods(split)
# Out:
# 100%|██████████| 8783/8783 [00:19<00:00, 462.16it/s]

# %%
np.mean(IS_quotients), np.mean(IS_quotient_prods)
# Out:
# (1.834885035752728, 4.099207245485309e-25)

# %%
n_obs = split["state"] .max() + 1
n_act = split["action"].max() + 1

n_obs, n_act
# Out:
# (752, 25)

# %%
def get_dataset(split, padding=False, seed=None, overwrite=False):
    set_all_seeds(seed)

    path = os.path.join(dir_data, "dataset.parquet")
    if os.path.exists(path) and not overwrite: return pd.read_parquet(path)

    dataset = {
        "id": [],
        "t": [],
        "obs_init": [],
        "obs": [],
        "act": [],
        "rew": [],
        "obs_next": [],
        "probs_init": [],
        "probs_init_behavior": [],
        "probs": [],
        "probs_behavior": [],
        "probs_next": [],
        "probs_next_behavior": [],
    }

    for i in range(len(split)):
        id = split.loc[i, "icustayid"]
        t  = split.loc[i, "bloc"] - 1 # type: ignore

        if i == 0 or split.loc[i-1, "icustayid"] != id:
            obs_init            = split.loc[i, "state"]
            probs_init          = split.loc[i, "model_probs"]
            probs_init_behavior = split.loc[i, "phys_probs"]

        if i == len(split) - 1 or split.loc[i+1, "icustayid"] != id:
            if not padding: continue

            obs = split.loc[i,   "state"]
            act = split.loc[i-1, "action"]
            rew = 0
            obs_next = obs

            probs          = split.loc[i, "model_probs"]
            probs_behavior = split.loc[i, "phys_probs"]
            probs_next = probs
            probs_next_behavior = probs_behavior

        else:
            obs      = split.loc[i, "state"]
            act      = split.loc[i, "action"]
            rew      = split.loc[i+1, "reward"]
            obs_next = split.loc[i+1, "state"]

            probs               = split.loc[i, "model_probs"]
            probs_behavior      = split.loc[i, "phys_probs"]
            probs_next          = split.loc[i+1, "model_probs"]
            probs_next_behavior = split.loc[i+1, "phys_probs"]

        dataset["id"].append(id)
        dataset["t"] .append(t)

        dataset["obs_init"].append(obs_init)
        dataset["obs"]     .append(obs)
        dataset["act"]     .append(act)
        dataset["rew"]     .append(rew)
        dataset["obs_next"].append(obs_next)

        dataset["probs_init"]         .append(probs_init)
        dataset["probs_init_behavior"].append(probs_init_behavior)
        dataset["probs"]              .append(probs)
        dataset["probs_behavior"]     .append(probs_behavior)
        dataset["probs_next"]         .append(probs_next)
        dataset["probs_next_behavior"].append(probs_next_behavior)

    dataset = pd.DataFrame(dataset)
    dataset.to_parquet(path)

    return dataset

# %%
def dataset_evluation_to_behavior(df):
    column_names = [
        "id", "t",
        "obs_init", "obs", "act", "rew", "obs_next",
        "probs_init_behavior", "probs_behavior", "probs_next_behavior",
    ]
    rename_columns = {
        "probs_init_behavior": "probs_init",
        "probs_behavior": "probs",
        "probs_next_behavior": "probs_next",
    }

    return df[column_names].rename(columns=rename_columns)

# %%
dataset = {}

x = get_dataset(split, padding=True, seed=0)
y = dataset_evluation_to_behavior(x)

dataset["evaluation"] = x
dataset["behavior"]   = y

# %%
split.head(16)
# Out:
#     bloc  icustayid  state  action  outcome  reward  \
# 0      1   30001446    712      12        0       0
# 1      2   30001446    185      22        0       0
# 2      3   30001446    185      16        0       0
# 3      4   30001446    388      11        0       0
# 4      5   30001446    712      10        0       0
# 5      6   30001446    388       5        0       0
# 6      7   30001446    534       5        0       0
# 7      8   30001446    534      20        0       0
# 8      9   30001446    185      20        0       0
# 9     10   30001446    751      -1        0     100
# 10     1   30002925    557      20        0       0
# 11     2   30002925     61       5        0       0
# 12     3   30002925     61       5        0       0
# 13     4   30002925    122       5        0       0
# 14     5   30002925    751      -1        0     100
# 15     1   30003202    694      20        0       0
#
#                                           model_probs  \
# 0   [0.00041666667675599456, 0.0004166666767559945...
# 1   [0.00041666667675599456, 0.0004166666767559945...
# 2   [0.00041666667675599456, 0.0004166666767559945...
# 3   [0.00041666667675599456, 0.0004166666767559945...
# 4   [0.00041666667675599456, 0.0004166666767559945...
# 5   [0.00041666667675599456, 0.0004166666767559945...
# 6   [0.00041666667675599456, 0.0004166666767559945...
# 7   [0.00041666667675599456, 0.0004166666767559945...
# 8   [0.00041666667675599456, 0.0004166666767559945...
# 9   [0.00041666667675599456, 0.0004166666767559945...
# 10  [0.00041666667675599456, 0.0004166666767559945...
# 11  [0.00041666667675599456, 0.0004166666767559945...
# 12  [0.00041666667675599456, 0.0004166666767559945...
# 13  [0.00041666667675599456, 0.0004166666767559945...
# 14  [0.00041666667675599456, 0.0004166666767559945...
# 15  [0.00041666667675599456, 0.0004166666767559945...
#
#                                            phys_probs
# 0   [0.06513158977031708, 0.002605263376608491, 0....
# 1   [0.0623076930642128, 0.0010000000474974513, 0....
# 2   [0.0623076930642128, 0.0010000000474974513, 0....
# 3   [0.05400000140070915, 0.0020000000949949026, 0...
# 4   [0.06513158977031708, 0.002605263376608491, 0....
# 5   [0.05400000140070915, 0.0020000000949949026, 0...
# 6   [0.07669013738632202, 0.0033333334140479565, 0...
# 7   [0.07669013738632202, 0.0033333334140479565, 0...
# 8   [0.0623076930642128, 0.0010000000474974513, 0....
# 9   [0.0623076930642128, 0.0010000000474974513, 0....
# 10  [0.09317646920681, 0.0020000000949949026, 0.00...
# 11  [0.1197209283709526, 0.004604651127010584, 0.0...
# 12  [0.1197209283709526, 0.004604651127010584, 0.0...
# 13  [0.1429603099822998, 0.00083333341171965, 0.00...
# 14  [0.1429603099822998, 0.00083333341171965, 0.00...
# 15  [0.08789719641208649, 0.0015420560957863927, 0...

# %%
dataset["evaluation"].head(16)
# Out:
#           id  t  obs_init  obs  act  rew  obs_next  \
# 0   30001446  0       712  712   12    0       185
# 1   30001446  1       712  185   22    0       185
# 2   30001446  2       712  185   16    0       388
# 3   30001446  3       712  388   11    0       712
# 4   30001446  4       712  712   10    0       388
# 5   30001446  5       712  388    5    0       534
# 6   30001446  6       712  534    5    0       534
# 7   30001446  7       712  534   20    0       185
# 8   30001446  8       712  185   20  100       751
# 9   30001446  9       712  751   20    0       751
# 10  30002925  0       557  557   20    0        61
# 11  30002925  1       557   61    5    0        61
# 12  30002925  2       557   61    5    0       122
# 13  30002925  3       557  122    5  100       751
# 14  30002925  4       557  751    5    0       751
# 15  30003202  0       694  694   20    0       219
#
#                                            probs_init  \
# 0   [0.00041666667675599456, 0.0004166666767559945...
# 1   [0.00041666667675599456, 0.0004166666767559945...
# 2   [0.00041666667675599456, 0.0004166666767559945...
# 3   [0.00041666667675599456, 0.0004166666767559945...
# 4   [0.00041666667675599456, 0.0004166666767559945...
# 5   [0.00041666667675599456, 0.0004166666767559945...
# 6   [0.00041666667675599456, 0.0004166666767559945...
# 7   [0.00041666667675599456, 0.0004166666767559945...
# 8   [0.00041666667675599456, 0.0004166666767559945...
# 9   [0.00041666667675599456, 0.0004166666767559945...
# 10  [0.00041666667675599456, 0.0004166666767559945...
# 11  [0.00041666667675599456, 0.0004166666767559945...
# 12  [0.00041666667675599456, 0.0004166666767559945...
# 13  [0.00041666667675599456, 0.0004166666767559945...
# 14  [0.00041666667675599456, 0.0004166666767559945...
# 15  [0.00041666667675599456, 0.0004166666767559945...
#
#                                   probs_init_behavior  \
# 0   [0.06513158977031708, 0.002605263376608491, 0....
# 1   [0.06513158977031708, 0.002605263376608491, 0....
# 2   [0.06513158977031708, 0.002605263376608491, 0....
# 3   [0.06513158977031708, 0.002605263376608491, 0....
# 4   [0.06513158977031708, 0.002605263376608491, 0....
# 5   [0.06513158977031708, 0.002605263376608491, 0....
# 6   [0.06513158977031708, 0.002605263376608491, 0....
# 7   [0.06513158977031708, 0.002605263376608491, 0....
# 8   [0.06513158977031708, 0.002605263376608491, 0....
# 9   [0.06513158977031708, 0.002605263376608491, 0....
# 10  [0.09317646920681, 0.0020000000949949026, 0.00...
# 11  [0.09317646920681, 0.0020000000949949026, 0.00...
# 12  [0.09317646920681, 0.0020000000949949026, 0.00...
# 13  [0.09317646920681, 0.0020000000949949026, 0.00...
# 14  [0.09317646920681, 0.0020000000949949026, 0.00...
# 15  [0.08789719641208649, 0.0015420560957863927, 0...
#
#                                                 probs  \
# 0   [0.00041666667675599456, 0.0004166666767559945...
# 1   [0.00041666667675599456, 0.0004166666767559945...
# 2   [0.00041666667675599456, 0.0004166666767559945...
# 3   [0.00041666667675599456, 0.0004166666767559945...
# 4   [0.00041666667675599456, 0.0004166666767559945...
# 5   [0.00041666667675599456, 0.0004166666767559945...
# 6   [0.00041666667675599456, 0.0004166666767559945...
# 7   [0.00041666667675599456, 0.0004166666767559945...
# 8   [0.00041666667675599456, 0.0004166666767559945...
# 9   [0.00041666667675599456, 0.0004166666767559945...
# 10  [0.00041666667675599456, 0.0004166666767559945...
# 11  [0.00041666667675599456, 0.0004166666767559945...
# 12  [0.00041666667675599456, 0.0004166666767559945...
# 13  [0.00041666667675599456, 0.0004166666767559945...
# 14  [0.00041666667675599456, 0.0004166666767559945...
# 15  [0.00041666667675599456, 0.0004166666767559945...
#
#                                        probs_behavior  \
# 0   [0.06513158977031708, 0.002605263376608491, 0....
# 1   [0.0623076930642128, 0.0010000000474974513, 0....
# 2   [0.0623076930642128, 0.0010000000474974513, 0....
# 3   [0.05400000140070915, 0.0020000000949949026, 0...
# 4   [0.06513158977031708, 0.002605263376608491, 0....
# 5   [0.05400000140070915, 0.0020000000949949026, 0...
# 6   [0.07669013738632202, 0.0033333334140479565, 0...
# 7   [0.07669013738632202, 0.0033333334140479565, 0...
# 8   [0.0623076930642128, 0.0010000000474974513, 0....
# 9   [0.0623076930642128, 0.0010000000474974513, 0....
# 10  [0.09317646920681, 0.0020000000949949026, 0.00...
# 11  [0.1197209283709526, 0.004604651127010584, 0.0...
# 12  [0.1197209283709526, 0.004604651127010584, 0.0...
# 13  [0.1429603099822998, 0.00083333341171965, 0.00...
# 14  [0.1429603099822998, 0.00083333341171965, 0.00...
# 15  [0.08789719641208649, 0.0015420560957863927, 0...
#
#                                            probs_next  \
# 0   [0.00041666667675599456, 0.0004166666767559945...
# 1   [0.00041666667675599456, 0.0004166666767559945...
# 2   [0.00041666667675599456, 0.0004166666767559945...
# 3   [0.00041666667675599456, 0.0004166666767559945...
# 4   [0.00041666667675599456, 0.0004166666767559945...
# 5   [0.00041666667675599456, 0.0004166666767559945...
# 6   [0.00041666667675599456, 0.0004166666767559945...
# 7   [0.00041666667675599456, 0.0004166666767559945...
# 8   [0.00041666667675599456, 0.0004166666767559945...
# 9   [0.00041666667675599456, 0.0004166666767559945...
# 10  [0.00041666667675599456, 0.0004166666767559945...
# 11  [0.00041666667675599456, 0.0004166666767559945...
# 12  [0.00041666667675599456, 0.0004166666767559945...
# 13  [0.00041666667675599456, 0.0004166666767559945...
# 14  [0.00041666667675599456, 0.0004166666767559945...
# 15  [0.00041666667675599456, 0.0004166666767559945...
#
#                                   probs_next_behavior
# 0   [0.0623076930642128, 0.0010000000474974513, 0....
# 1   [0.0623076930642128, 0.0010000000474974513, 0....
# 2   [0.05400000140070915, 0.0020000000949949026, 0...
# 3   [0.06513158977031708, 0.002605263376608491, 0....
# 4   [0.05400000140070915, 0.0020000000949949026, 0...
# 5   [0.07669013738632202, 0.0033333334140479565, 0...
# 6   [0.07669013738632202, 0.0033333334140479565, 0...
# 7   [0.0623076930642128, 0.0010000000474974513, 0....
# 8   [0.0623076930642128, 0.0010000000474974513, 0....
# 9   [0.0623076930642128, 0.0010000000474974513, 0....
# 10  [0.1197209283709526, 0.004604651127010584, 0.0...
# 11  [0.1197209283709526, 0.004604651127010584, 0.0...
# 12  [0.1429603099822998, 0.00083333341171965, 0.00...
# 13  [0.1429603099822998, 0.00083333341171965, 0.00...
# 14  [0.1429603099822998, 0.00083333341171965, 0.00...
# 15  [0.08027026802301407, 0.0024999999441206455, 0...

# %%
IS_weights = dataset["evaluation"].apply(
    lambda x: x["probs"][ x["act"] ] / x["probs_behavior"][ x["act"] ],
    axis=1,
)

IS_weights_prod = get_w_prod(dataset["evaluation"], IS_weights)

# %%
f = get_get_policy_value(dataset["evaluation"])
f.__name__ = "OnPE evaluation"
estimators_OnPE = { "behavior": f, }

def get_estimators_IS(dataset, IS_weights):

    f = get_get_policy_value(dataset, IS_weights)
    g = lambda gamma, scale=True: f(gamma, scale, weighted=False)
    g.__name__ = "SIS"
    h = lambda gamma, scale=True: f(gamma, scale, weighted=True)
    h.__name__ = "WIS"

    return { False: g, True: h, }

estimators_IS = get_estimators_IS(dataset["evaluation"], IS_weights)

# %%
tabular_dice = {
    kind: TabularDice(dataset[kind], n_obs, n_act, os.path.join(dir_data, kind), verbosity=1)
        for kind in kinds
}
# Out:
# trying to load auxiliary estimates from data/medical_rl/sepsis_mimic_iv/v1.0/behavior
# failed to load
# creating auxiliary estimates from dataset
# 100%|██████████| 104720/104720 [08:12<00:00, 212.59it/s]
# saving auxiliary estimates
# saved data/medical_rl/sepsis_mimic_iv/v1.0/behavior/d0_bar.npy
# saved data/medical_rl/sepsis_mimic_iv/v1.0/behavior/dD_bar.npy
# saved data/medical_rl/sepsis_mimic_iv/v1.0/behavior/P_bar.npy
# saved data/medical_rl/sepsis_mimic_iv/v1.0/behavior/r_bar.npy
# saved data/medical_rl/sepsis_mimic_iv/v1.0/behavior/n.npy
# trying to load auxiliary estimates from data/medical_rl/sepsis_mimic_iv/v1.0/evaluation
# failed to load
# creating auxiliary estimates from dataset
# 100%|██████████| 104720/104720 [08:10<00:00, 213.59it/s]
# saving auxiliary estimates
# saved data/medical_rl/sepsis_mimic_iv/v1.0/evaluation/d0_bar.npy
# saved data/medical_rl/sepsis_mimic_iv/v1.0/evaluation/dD_bar.npy
# saved data/medical_rl/sepsis_mimic_iv/v1.0/evaluation/P_bar.npy
# saved data/medical_rl/sepsis_mimic_iv/v1.0/evaluation/r_bar.npy
# saved data/medical_rl/sepsis_mimic_iv/v1.0/evaluation/n.npy

# %% [markdown]
# ### Histograms

# %%
plot_histogram(
    data=IS_weights, bins=100, moving_average_radius=None,
    suptitle=f"Sepsis MimicIV {version} - policy ratios", xlabel="policy ratios",
    xscale=True, yscale=True,
    true_mean=1,
    dir=dir_images,
)

# %%
plot_histogram(
    data=IS_weights_prod, bins=100,
    suptitle=f"Sepsis MimicIV {version} - policy ratio products", xlabel="policy ratio products",
    xscale=True, yscale=True,
    true_mean=1,
    dir=dir_images,
)

# %% [markdown]
# ### Quick Evaluation

# %%
def evaluate_all(gamma):
    title = f"{gamma=}"
    print(title)
    print("-"*len(title))

    pvs = {}

    pvs["OnPE behavior"] = estimators_OnPE["behavior"](gamma, scale=False)

    for k, b in zip(["SIS", "WIS"], [False, True]):
        pvs[k] = estimators_IS[b](gamma, scale=False)

    if gamma < 1:
        for weighted in [False, True]:
            for kind in kinds:
                pvs[f"DICE ({weighted=}, {kind=})"] = tabular_dice[kind].solve(
                    gamma, projected=True, modified=True, weighted=weighted)[0] / (1 - gamma)

    print( pd.Series(pvs) )

# %%
evaluate_all(gamma=0.9999)
# Out:
# gamma=0.9999
# ------------
# OnPE behavior                                 75.814552
# SIS                                            0.113323
# WIS                                           99.752834
# DICE (weighted=False, kind='behavior')      1849.232891
# DICE (weighted=False, kind='evaluation')    2885.481165
# DICE (weighted=True, kind='behavior')         54.037760
# DICE (weighted=True, kind='evaluation')        4.275508
# dtype: float64

# %%
evaluate_all(gamma=1.0)
# Out:
# gamma=1.0
# ---------
# OnPE behavior    75.885233
# SIS               0.113478
# WIS              99.889131
# dtype: float64

# %% [markdown]
# ### Filter Trajectories

# %%
def get_ids_filtered_by_IS_weights_prod(
        dataset, IS_weights_prod,
        lower=-float("inf"), upper=float("inf"),
    ):
    return np.array([
        id
            for id, IS_weight_prod in zip(dataset["id"].unique(), IS_weights_prod)
            if lower <= IS_weight_prod <= upper
    ])

def get_IS_filtered(gamma, lower, upper, verbosity=1):

    print(f"filtering trajectories for IS_weight_prods within [{lower}, {upper}]")
    ids_filtered = get_ids_filtered_by_IS_weights_prod(
        dataset["evaluation"], IS_weights_prod,
        lower=lower, upper=upper, )

    if verbosity >= 1:
        a = ids_filtered.size
        b = dataset["evaluation"]["id"].unique().size
        print(f"only using {a / b} of trajectories")
        print(f"deleting {b - a} trajectories")

    l = IS_weights_prod >= lower
    u = IS_weights_prod <= upper

    if verbosity >= 2:
        plot_histogram(
            data=IS_weights_prod[l * u], bins=100,
            suptitle=f"RRT MIMIC - policy ratio products filtered in [{lower}, {upper}]",
            xlabel="policy ratio products",
            xscale=True, yscale=True,
        )

    if verbosity >= 0:
        f = dataset["evaluation"]["id"].isin(ids_filtered)
        estimator_OnPE = get_get_policy_value(dataset["evaluation"][f])
        estimators_IS = get_estimators_IS(dataset["evaluation"][f], IS_weights[f])

        print( "OnPE behavior:", estimator_OnPE(gamma, scale=False) )
        print( "SIS:", estimators_IS[False](gamma, scale=False) )
        print( "WIS:", estimators_IS[True] (gamma, scale=False) )

# %%
for upper in [float("inf"), 0.01]:
    print("\n", "#", "-"*64, "#", "\n")
    get_IS_filtered(1.0, -float("inf"), upper)
# Out:
#  # ---------------------------------------------------------------- #
#
# filtering trajectories for IS_weight_prods within [-inf, inf]
# only using 1.0 of trajectories
# deleting 0 trajectories
# OnPE behavior: 75.88523283616077
# SIS: 0.1134780263223366
# WIS: 99.88913113236016
#
#  # ---------------------------------------------------------------- #
#
# filtering trajectories for IS_weight_prods within [-inf, 0.01]
# only using 0.9993168621200046 of trajectories
# deleting 6 trajectories
# OnPE behavior: 75.86874786373477
# SIS: 0.00016226595688871654
# WIS: 56.283033663622405

# %% [markdown]
# # `get_pvs`

# %%
from dice_rl_TU_Vienna.estimators.get import get_pv_s_OnPE, get_pv_s_OffPE
from dice_rl_TU_Vienna.estimators.get import get_gammas_log10

from dice_rl_TU_Vienna.estimators.tabular.tabular_vafe          import TabularVafe
from dice_rl_TU_Vienna.estimators.tabular.tabular_dice          import TabularDice
from dice_rl_TU_Vienna.estimators.tabular.tabular_dual_dice     import TabularDualDice
from dice_rl_TU_Vienna.estimators.tabular.tabular_gradient_dice import TabularGradientDice

from dice_rl_TU_Vienna.utils.general import iterate_print

gammas = get_gammas_log10()

dir_dataset = dir_data

projected = True
modified = True
lamda = 1e-6


estimators_OffPE = {}
estimators_VAFE  = {}
estimators_DICE  = {}

for kind in iterate_print(kinds, "kind"):
    E = [
        estimator_type(
            dataset[kind],
            n_obs, n_act,
            os.path.join(dir_dataset, kind),
            verbosity=1,
        )
            for estimator_type in [
                TabularVafe, TabularDice, TabularDualDice, TabularGradientDice, ]
    ]

    estimators_OffPE[kind] = E
    estimators_VAFE [kind] = E[:1]
    estimators_DICE [kind] = E[1:]
# Out:
# kind=behavior
# trying to load auxiliary estimates from data/medical_rl/sepsis_mimic_iv/v1.0/behavior
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/behavior/d0_bar.npy
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/behavior/dD_bar.npy
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/behavior/P_bar.npy
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/behavior/r_bar.npy
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/behavior/n.npy
# trying to load auxiliary estimates from data/medical_rl/sepsis_mimic_iv/v1.0/behavior
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/behavior/d0_bar.npy
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/behavior/dD_bar.npy
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/behavior/P_bar.npy
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/behavior/r_bar.npy
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/behavior/n.npy
# trying to load auxiliary estimates from data/medical_rl/sepsis_mimic_iv/v1.0/behavior
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/behavior/d0_bar.npy
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/behavior/dD_bar.npy
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/behavior/P_bar.npy
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/behavior/r_bar.npy
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/behavior/n.npy
# trying to load auxiliary estimates from data/medical_rl/sepsis_mimic_iv/v1.0/behavior
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/behavior/d0_bar.npy
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/behavior/dD_bar.npy
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/behavior/P_bar.npy
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/behavior/r_bar.npy
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/behavior/n.npy
# kind=evaluation
# trying to load auxiliary estimates from data/medical_rl/sepsis_mimic_iv/v1.0/evaluation
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/evaluation/d0_bar.npy
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/evaluation/dD_bar.npy
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/evaluation/P_bar.npy
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/evaluation/r_bar.npy
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/evaluation/n.npy
# trying to load auxiliary estimates from data/medical_rl/sepsis_mimic_iv/v1.0/evaluation
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/evaluation/d0_bar.npy
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/evaluation/dD_bar.npy
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/evaluation/P_bar.npy
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/evaluation/r_bar.npy
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/evaluation/n.npy
# trying to load auxiliary estimates from data/medical_rl/sepsis_mimic_iv/v1.0/evaluation
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/evaluation/d0_bar.npy
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/evaluation/dD_bar.npy
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/evaluation/P_bar.npy
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/evaluation/r_bar.npy
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/evaluation/n.npy
# trying to load auxiliary estimates from data/medical_rl/sepsis_mimic_iv/v1.0/evaluation
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/evaluation/d0_bar.npy
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/evaluation/dD_bar.npy
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/evaluation/P_bar.npy
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/evaluation/r_bar.npy
# loaded data/medical_rl/sepsis_mimic_iv/v1.0/evaluation/n.npy

# %%
pvs_OnPE = {
    "behavior": get_pv_s_OnPE(
        estimator_s=estimators_OnPE["behavior"],
        gamma_s=gammas,
    )
}

# %%
pvs_IS = {
    weighted: get_pv_s_OnPE(
        estimator_s=estimators_IS[weighted],
        gamma_s=gammas,
    )
        for weighted in [False, True]
}

# %%
pvs_VAFE = {}
pvs_DICE = { kind: {} for kind in kinds }

for kind in kinds:
    dir = os.path.join(dir_dataset, kind)

    file = os.path.join(dir, "pvs_VAFE.npy")

    if os.path.exists(file):
        arr = np.load(file)
    else:
        arr = get_pv_s_OffPE(
            estimator_s=estimators_VAFE[kind],
            gamma_s=gammas,
            projected=projected, weighted=None,
            modified=modified, lamda=lamda,
            verbosity=2,
        )
        np.save(file, arr)

    pvs_VAFE[kind] = arr

    for weighted, postfix in zip([False, True], ["simple", "weighted"]):

        file = os.path.join(dir, f"pvs_DICE_{postfix}.npy")

        if os.path.exists(file):
            arr = np.load(file)
        else:
            arr = get_pv_s_OffPE(
                estimators_DICE[kind],
                gammas,
                projected=projected, weighted=weighted,
                modified=modified, lamda=lamda,
                verbosity=2,
            )
            np.save(file, arr)

        pvs_DICE[kind][weighted] = arr
# Out:
# 100%|██████████| 17/17 [03:25<00:00, 12.09s/it]
# 100%|██████████| 17/17 [00:54<00:00,  3.20s/it]
# 100%|██████████| 17/17 [11:59<00:00, 42.34s/it]
#   0%|          | 0/17 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[44], line 30
#      28     arr = np.load(file)
#      29 else:
# ---> 30     arr = get_pv_s_OffPE(
#      31         estimators_DICE[kind],
#      32         gammas,
#      33         projected=projected, weighted=weighted,
#      34         modified=modified, lamda=lamda,
#      35         verbosity=2,
#      36     )
#      37     np.save(file, arr)
#      39 pvs_DICE[kind][weighted] = arr
#
# File ~/Documents/Masterarbeit/dice_rl_sepsis/dice_rl_TU_Vienna/estimators/get.py:106, in get_pv_s_OffPE(estimator_s, gamma_s, projected, weighted, modified, lamda, verbosity)
#     101 def get_pv_s_OffPE(
#     102         estimator_s, gamma_s,
#     103         projected, weighted, modified, lamda,
#     104         verbosity=0, ):
# --> 106     return apply_get(
#     107         get_pv_OffPE, "pv",
#     108         estimator_s, gamma_s,
#     109         verbosity,
#     110         projected, weighted, modified, lamda, )
#
# File ~/Documents/Masterarbeit/dice_rl_sepsis/dice_rl_TU_Vienna/estimators/get.py:64, in apply_get(get, file_name, estimator_s, gamma_s, verbosity, *args)
#      62     pbar = estimator_s
#      63     if verbosity == 1: pbar = tqdm(pbar)
# ---> 64     return np.array([
#      65         apply_get(
#      66             get, file_name,
#      67             estimator, gamma_s,
#      68             verbosity,
#      69             *args
#      70         )
#      71             for estimator in pbar
#      72     ])
#      74 if isinstance(gamma_s, list) or isinstance(gamma_s, np.ndarray):
#      75     pbar = gamma_s
#
# File ~/Documents/Masterarbeit/dice_rl_sepsis/dice_rl_TU_Vienna/estimators/get.py:65, in <listcomp>(.0)
#      62     pbar = estimator_s
#      63     if verbosity == 1: pbar = tqdm(pbar)
#      64     return np.array([
# ---> 65         apply_get(
#      66             get, file_name,
#      67             estimator, gamma_s,
#      68             verbosity,
#      69             *args
#      70         )
#      71             for estimator in pbar
#      72     ])
#      74 if isinstance(gamma_s, list) or isinstance(gamma_s, np.ndarray):
#      75     pbar = gamma_s
#
# File ~/Documents/Masterarbeit/dice_rl_sepsis/dice_rl_TU_Vienna/estimators/get.py:77, in apply_get(get, file_name, estimator_s, gamma_s, verbosity, *args)
#      75     pbar = gamma_s
#      76     if verbosity == 2: pbar = tqdm(pbar)
# ---> 77     array = np.array([
#      78         apply_get(
#      79             get, file_name,
#      80             estimator_s, gamma,
#      81             verbosity,
#      82             *args
#      83         )
#      84             for gamma in pbar
#      85     ])
#      87     return array
#      89 return get(estimator_s, gamma_s, *args)
#
# File ~/Documents/Masterarbeit/dice_rl_sepsis/dice_rl_TU_Vienna/estimators/get.py:78, in <listcomp>(.0)
#      75     pbar = gamma_s
#      76     if verbosity == 2: pbar = tqdm(pbar)
#      77     array = np.array([
# ---> 78         apply_get(
#      79             get, file_name,
#      80             estimator_s, gamma,
#      81             verbosity,
#      82             *args
#      83         )
#      84             for gamma in pbar
#      85     ])
#      87     return array
#      89 return get(estimator_s, gamma_s, *args)
#
# File ~/Documents/Masterarbeit/dice_rl_sepsis/dice_rl_TU_Vienna/estimators/get.py:89, in apply_get(get, file_name, estimator_s, gamma_s, verbosity, *args)
#      77     array = np.array([
#      78         apply_get(
#      79             get, file_name,
#    (...)
#      84             for gamma in pbar
#      85     ])
#      87     return array
# ---> 89 return get(estimator_s, gamma_s, *args)
#
# File ~/Documents/Masterarbeit/dice_rl_sepsis/dice_rl_TU_Vienna/estimators/get.py:30, in get_pv_OffPE(estimator, gamma, *args)
#      27 def get_pv_OffPE(estimator, gamma, *args):
#      28     projected, weighted, modified, lamda = args
# ---> 30     pv, *_ = estimator.solve(
#      31         gamma, projected,
#      32         weighted=weighted,
#      33         modified=modified, lamda=lamda,
#      34     )
#      35     return pv
#
# File ~/Documents/Masterarbeit/dice_rl_sepsis/dice_rl_TU_Vienna/estimators/tabular/tabular_dice.py:40, in TabularDice.solve(self, gamma, projected, **kwargs)
#      36 def solve(self, gamma, projected, **kwargs):
#      38     weighted = kwargs["weighted"]
# ---> 40     w_hat, info = self.solve_sdc(gamma, projected, **kwargs)
#      41     rho_hat = self.solve_pv(w_hat, weighted)
#      43     return rho_hat, w_hat, info
#
# File ~/Documents/Masterarbeit/dice_rl_sepsis/dice_rl_TU_Vienna/estimators/tabular/tabular_gradient_dice.py:28, in TabularGradientDice.solve_sdc(self, gamma, projected, **kwargs)
#      25 D_ = np.diag(dD_)
#      27 A = D_ - gamma * P_.T
# ---> 28 B = safe_divide(A.T, dD_, zero_div_zero=-1)
#      30 x = np.matmul(B, A)
#      31 y = lamda / n * np.outer(d0_, d0_)
#
# File ~/Documents/.venvs/dice_rl_TU_Vienna/lib/python3.11/site-packages/numpy/lib/function_base.py:2372, in vectorize.__call__(self, *args, **kwargs)
#    2369     self._init_stage_2(*args, **kwargs)
#    2370     return self
# -> 2372 return self._call_as_normal(*args, **kwargs)
#
# File ~/Documents/.venvs/dice_rl_TU_Vienna/lib/python3.11/site-packages/numpy/lib/function_base.py:2365, in vectorize._call_as_normal(self, *args, **kwargs)
#    2362     vargs = [args[_i] for _i in inds]
#    2363     vargs.extend([kwargs[_n] for _n in names])
# -> 2365 return self._vectorize_call(func=func, args=vargs)
#
# File ~/Documents/.venvs/dice_rl_TU_Vienna/lib/python3.11/site-packages/numpy/lib/function_base.py:2455, in vectorize._vectorize_call(self, func, args)
#    2452 # Convert args to object arrays first
#    2453 inputs = [asanyarray(a, dtype=object) for a in args]
# -> 2455 outputs = ufunc(*inputs)
#    2457 if ufunc.nout == 1:
#    2458     res = asanyarray(outputs, dtype=otypes[0])
#
# File ~/Documents/.venvs/dice_rl_TU_Vienna/lib/python3.11/site-packages/numpy/lib/function_base.py:2356, in vectorize._call_as_normal.<locals>.func(*vargs)
#    2353 inds = [_i for _i in range(nargs) if _i not in excluded]
#    2354 the_args = list(args)
# -> 2356 def func(*vargs):
#    2357     for _n, _i in enumerate(inds):
#    2358         the_args[_i] = vargs[_n]
#
# KeyboardInterrupt:

# %%
pv_OnPE = {
    "behavior": get_pv_s_OnPE(
        estimator_s=lambda gamma: estimators_OnPE["behavior"](gamma, scale=False),
        gamma_s=1.0,
    )
}

# %%
pv_IS = {
    weighted: get_pv_s_OnPE(
        estimator_s=lambda gamma: estimators_IS[weighted](gamma, scale=False),
        gamma_s=1.0,
    )
        for weighted in [False, True]
}

# %% [markdown]
# # Plot

# %% [markdown]
# ## Policy Values

# %%
env_title = "Sepsis MimicIV"

colors_OnPE = ["lightgrey", "grey"]
colors_VAFE = ["blue"]
colors_DICE = ["orange", "green", "red"]
color_IS = "pink"

markers_OnPE = ["v", "^"]
markers_VAFE = ["1"]
markers_DICE = ["2", "3", "4"]
marker_IS = "x"

# %%
def plot_pvs_sepsis_mimic_iv(kind, weighted):

    estimators = estimators_OffPE[kind] + ( [ estimators_OnPE[kind] ] if kind == "behavior" else [ estimators_IS[weighted] ] )

    pvs = list(pvs_VAFE[kind]) + list(pvs_DICE[kind][weighted]) + ( [ pvs_OnPE[kind] ] if kind == "behavior" else [ pvs_IS[weighted] ] )
    pv_ref = None
    pv_lims = [ pv_OnPE[kind] ] if kind == "behavior" else [ pv_IS[weighted] ]
    pv_lim_ref = None

    labels = None
    c  = colors_VAFE  + colors_DICE  + ( [ color_IS ]  if kind == "evaluation" else [ colors_OnPE[0] ] )
    m  = markers_VAFE + markers_DICE + ( [ marker_IS ] if kind == "evaluation" else [ markers_OnPE[0] ] )
    cl = [ color_IS ]  if kind == "evaluation" else [ colors_OnPE[0] ]
    ml = [ marker_IS ] if kind == "evaluation" else [ markers_OnPE[0] ]

    measure = "PVs"
    suptitle = f"{env_title} - {kind} - {measure}"

    one_minus_gamma = True
    errors = False
    xlabel = None
    ylabel = None
    scale_x = True
    scale_y = False
    scale_pv = True
    ylim = (-5, 105)
    legend = True
    dir = dir_images

    plot_pvs(
        estimators,
        gammas,
        projected, weighted,
        modified, lamda,
        #
        pvs, pv_lims, pv_ref, pv_lim_ref,
        labels,
        c, cl,
        m, ml,
        suptitle,
        one_minus_gamma, errors,
        xlabel, ylabel,
        scale_x, scale_y,
        scale_pv,
        ylim, legend,
        dir,
    )

# %%
for kind in kinds:
    for weighted in [False, True]:
        plot_pvs_sepsis_mimic_iv(kind, weighted)
